# %%
import pandas as pd
# Out:
# Running cells with 'cpython-3.13.15-windows-x86_64-none (3.13.15) (Python 3.13.15)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/mario/AppData/Roaming/uv/python/cpython-3.13.15-windows-x86_64-none/python.exe -m pip install ipykernel -U --force-reinstall'
